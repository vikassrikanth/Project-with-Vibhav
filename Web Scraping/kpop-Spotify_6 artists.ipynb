# %%
#install spotipy package before importing it
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

client_id = "8ab1396e148c47c69f4511ea9a7b9fa7" #Copy the client_id from spotify for developers
client_secret = "896376cc2cc14ade97521aedeae8bdf7" #Copy the client_id from spotify for developers

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = ["BLACKPINK", "ITZY", "IZ*ONE", "LOONA", "LOOΠΔ 1/3", "ODD EYE CIRCLE", "LOONA/yyxy", "Stray Kids", "TWICE"] #chosen artist
artist_res = []
for x in range(0, len(name)):
    result = sp.search(name[x]) #search query
    #result=sp.search(q="pop")
    artist_res.append(result['tracks']['items'][0]['artists'])
    #print(result['tracks']['items'][0]['artists']

# %%
#Extract Artist's uri
artist_uri=[]
for i in range(0,len(artist_res)):
    artist_uri.append(artist_res[i][0]['uri'])
#Pull all of the artist's albums

# %%
artist_uri
# Out:
# ['spotify:artist:41MozSoPIsD1dJM0CLPjZF',
#  'spotify:artist:2KC9Qb60EaY0kW4eH68vr3',
#  'spotify:artist:5r1tUTxVSgvBHnoDuDODPH',
#  'spotify:artist:52zMTJCKluDlFwMQWmccY7',
#  'spotify:artist:4u9YxYzCjpMjnMcwNu9fzy',
#  'spotify:artist:5KPaeBm0fVfCSZLydp9jdy',
#  'spotify:artist:5JPKwLsHGaPIlxqHiF29e4',
#  'spotify:artist:2dIgFjalVxs4ThymZ67YCE',
#  'spotify:artist:7n2Ycct7Beij7Dj7meI4X0']

# %%
sp_albums = []
for i in range(0,len(artist_uri)):
    sp_albums.append(sp.artist_albums(artist_uri[i], album_type='album'))
#Store artist's albums' names' and uris in separate lists

# %%
sp_albums[0]
# Out:
# {'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF/albums?offset=0&limit=20&include_groups=album',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#      'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#      'id': '41MozSoPIsD1dJM0CLPjZF',
#      'name': 'BLACKPINK',
#      'type': 'artist',
#      'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7J4ASJD3IvdANlrPkmeVP0'},
#    'href': 'https://api.spotify.com/v1/albums/7J4ASJD3IvdANlrPkmeVP0',
#    'id': '7J4ASJD3IvdANlrPkmeVP0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27323c5b62995e1610ef9f7c137',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0223c5b62995e1610ef9f7c137',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485123c5b62995e1610ef9f7c137',
#      'width': 64}],
#    'name': 'BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -TOKYO DOME- (Live)',
#    'release_date': '2020-05-14',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:7J4ASJD3IvdANlrPkmeVP0'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#      'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#      'id': '41MozSoPIsD1dJM0CLPjZF',
#      'name': 'BLACKPINK',
#      'type': 'artist',
#      'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'IE',
#     'IS',
#     'IT',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SK',
#     'SV',
#     'TN',
#     'US',
#     'UY',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4i0XmhtxZBPxwpgNeJ1Tvg'},
#    'href': 'https://api.spotify.com/v1/albums/4i0XmhtxZBPxwpgNeJ1Tvg',
#    'id': '4i0XmhtxZBPxwpgNeJ1Tvg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b64959a23f88cff1370b602a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b64959a23f88cff1370b602a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b64959a23f88cff1370b602a',
#      'width': 64}],
#    'name': "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)",
#    'release_date': '2019-08-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4i0XmhtxZBPxwpgNeJ1Tvg'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#      'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#      'id': '41MozSoPIsD1dJM0CLPjZF',
#      'name': 'BLACKPINK',
#      'type': 'artist',
#      'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#    'available_markets': ['AE',
#     'BH',
#     'CY',
#     'HK',
#     'ID',
#     'IL',
#     'IN',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'MY',
#     'OM',
#     'PH',
#     'PS',
#     'QA',
#     'SA',
#     'SG',
#     'TH',
#     'TR',
#     'TW',
#     'VN'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1Q2x3A0YKL8IB7FYL82QiS'},
#    'href': 'https://api.spotify.com/v1/albums/1Q2x3A0YKL8IB7FYL82QiS',
#    'id': '1Q2x3A0YKL8IB7FYL82QiS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735415730d7def154e3f05d4a2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025415730d7def154e3f05d4a2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515415730d7def154e3f05d4a2',
#      'width': 64}],
#    'name': "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live",
#    'release_date': '2019-08-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1Q2x3A0YKL8IB7FYL82QiS'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#      'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#      'id': '41MozSoPIsD1dJM0CLPjZF',
#      'name': 'BLACKPINK',
#      'type': 'artist',
#      'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1dH4B2bWb5Ys7aszi9KWHA'},
#    'href': 'https://api.spotify.com/v1/albums/1dH4B2bWb5Ys7aszi9KWHA',
#    'id': '1dH4B2bWb5Ys7aszi9KWHA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734eb5d1d2cb8e591441903c23',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024eb5d1d2cb8e591441903c23',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514eb5d1d2cb8e591441903c23',
#      'width': 64}],
#    'name': 'BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KYOCERA DOME OSAKA"',
#    'release_date': '2019-03-13',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1dH4B2bWb5Ys7aszi9KWHA'},
#   {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#      'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#      'id': '41MozSoPIsD1dJM0CLPjZF',
#      'name': 'BLACKPINK',
#      'type': 'artist',
#      'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4cpZazoKuj3jD6x2GrSX2w'},
#    'href': 'https://api.spotify.com/v1/albums/4cpZazoKuj3jD6x2GrSX2w',
#    'id': '4cpZazoKuj3jD6x2GrSX2w',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b11340b8eba51d954ba51f68',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b11340b8eba51d954ba51f68',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b11340b8eba51d954ba51f68',
#      'width': 64}],
#    'name': 'BLACKPINK IN YOUR AREA',
#    'release_date': '2018-12-05',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:4cpZazoKuj3jD6x2GrSX2w'}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 5}

# %%
sp_albums[0]['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7J4ASJD3IvdANlrPkmeVP0'},
#   'href': 'https://api.spotify.com/v1/albums/7J4ASJD3IvdANlrPkmeVP0',
#   'id': '7J4ASJD3IvdANlrPkmeVP0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27323c5b62995e1610ef9f7c137',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0223c5b62995e1610ef9f7c137',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485123c5b62995e1610ef9f7c137',
#     'width': 64}],
#   'name': 'BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -TOKYO DOME- (Live)',
#   'release_date': '2020-05-14',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:7J4ASJD3IvdANlrPkmeVP0'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HN',
#    'HU',
#    'IE',
#    'IS',
#    'IT',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PL',
#    'PT',
#    'PY',
#    'RO',
#    'SE',
#    'SK',
#    'SV',
#    'TN',
#    'US',
#    'UY',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4i0XmhtxZBPxwpgNeJ1Tvg'},
#   'href': 'https://api.spotify.com/v1/albums/4i0XmhtxZBPxwpgNeJ1Tvg',
#   'id': '4i0XmhtxZBPxwpgNeJ1Tvg',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b64959a23f88cff1370b602a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b64959a23f88cff1370b602a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b64959a23f88cff1370b602a',
#     'width': 64}],
#   'name': "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)",
#   'release_date': '2019-08-30',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:4i0XmhtxZBPxwpgNeJ1Tvg'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#   'available_markets': ['AE',
#    'BH',
#    'CY',
#    'HK',
#    'ID',
#    'IL',
#    'IN',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'MY',
#    'OM',
#    'PH',
#    'PS',
#    'QA',
#    'SA',
#    'SG',
#    'TH',
#    'TR',
#    'TW',
#    'VN'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Q2x3A0YKL8IB7FYL82QiS'},
#   'href': 'https://api.spotify.com/v1/albums/1Q2x3A0YKL8IB7FYL82QiS',
#   'id': '1Q2x3A0YKL8IB7FYL82QiS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735415730d7def154e3f05d4a2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025415730d7def154e3f05d4a2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515415730d7def154e3f05d4a2',
#     'width': 64}],
#   'name': "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live",
#   'release_date': '2019-08-30',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:1Q2x3A0YKL8IB7FYL82QiS'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1dH4B2bWb5Ys7aszi9KWHA'},
#   'href': 'https://api.spotify.com/v1/albums/1dH4B2bWb5Ys7aszi9KWHA',
#   'id': '1dH4B2bWb5Ys7aszi9KWHA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734eb5d1d2cb8e591441903c23',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024eb5d1d2cb8e591441903c23',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514eb5d1d2cb8e591441903c23',
#     'width': 64}],
#   'name': 'BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KYOCERA DOME OSAKA"',
#   'release_date': '2019-03-13',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:1dH4B2bWb5Ys7aszi9KWHA'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4cpZazoKuj3jD6x2GrSX2w'},
#   'href': 'https://api.spotify.com/v1/albums/4cpZazoKuj3jD6x2GrSX2w',
#   'id': '4cpZazoKuj3jD6x2GrSX2w',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b11340b8eba51d954ba51f68',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b11340b8eba51d954ba51f68',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b11340b8eba51d954ba51f68',
#     'width': 64}],
#   'name': 'BLACKPINK IN YOUR AREA',
#   'release_date': '2018-12-05',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:4cpZazoKuj3jD6x2GrSX2w'}]

# %%
album_names = []
album_uris = []



for i in range(len(sp_albums[0]['items'])):
    album_names.append(sp_albums[0]['items'][i]['name'])
    album_uris.append(sp_albums[0]['items'][i]['uri'])

#album_names
album_uris
# Out:
# ['spotify:album:7J4ASJD3IvdANlrPkmeVP0',
#  'spotify:album:4i0XmhtxZBPxwpgNeJ1Tvg',
#  'spotify:album:1Q2x3A0YKL8IB7FYL82QiS',
#  'spotify:album:1dH4B2bWb5Ys7aszi9KWHA',
#  'spotify:album:4cpZazoKuj3jD6x2GrSX2w']

# %%
len(sp_albums[0]['items'])
# Out:
# 5

# %%
album_names = []
album_uris = []
for i in range(len())

# %%
album_names
# Out:
# ['BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -TOKYO DOME- (Live)',
#  "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)",
#  "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live",
#  'BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KYOCERA DOME OSAKA"',
#  'BLACKPINK IN YOUR AREA']

# %%
album_names = []
album_uris = []


for j in range(0, len(sp_albums)):
    for i in range(len(sp_albums[j]['items'])):
        album_names.append(sp_albums[j]['items'][i]['name'])
        album_uris.append(sp_albums[j]['items'][i]['uri'])

# %%
print(album_names)
# Out:
# ['BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -TOKYO DOME- (Live)', "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)", "BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live", 'BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KYOCERA DOME OSAKA"', 'BLACKPINK IN YOUR AREA', "IT'z ME", "It'z Me", 'Oneiric Diary', 'BLOOM*IZ', 'HEART*IZ', 'COLOR*IZ', 'Love & Evil', 'Max & Match', 'GO LIVE', 'GO LIVE', 'SKZ2020', 'SKZ2020', 'Clé : LEVANTER', 'Cle : LEVANTER', 'UNVEIL Stray Kids', 'Clé 2 : Yellow Wood', 'Clé 1 : MIROH', 'I am YOU', 'I am WHO', 'I am NOT', 'Mixtape', 'MORE & MORE', 'MORE & MORE', '&TWICE (Repackage)', '&TWICE (Repackage)', '&TWICE', '&TWICE', 'Feel Special', 'Feel Special', 'BDZ (Repackage)', 'The year of "YES"', 'The year of "YES"', 'YES or YES', 'YES or YES', 'BDZ', 'Summer Nights', 'Summer Nights', 'Merry & Happy', 'Merry & Happy', 'twicetagram', 'Twicetagram']

# %%
def albumSongs(uri):
    album = uri #assign album uri to a_name
    spotify_albums[album] = {} #Creates dictionary for that specific album
#Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    tracks = sp.album_tracks(album) #pull data on album tracks
    for n in range(len(tracks['items'])): #for each song track
        spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0
for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# Album BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -TOKYO DOME- (Live) songs has been added to spotify_albums dictionary
# Album BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live) songs has been added to spotify_albums dictionary
# Album BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live songs has been added to spotify_albums dictionary
# Album BLACKPINK ARENA TOUR 2018 "SPECIAL FINAL IN KYOCERA DOME OSAKA" songs has been added to spotify_albums dictionary
# Album BLACKPINK IN YOUR AREA songs has been added to spotify_albums dictionary
# Album IT'z ME songs has been added to spotify_albums dictionary
# Album It'z Me songs has been added to spotify_albums dictionary
# Album Oneiric Diary songs has been added to spotify_albums dictionary
# Album BLOOM*IZ songs has been added to spotify_albums dictionary
# Album HEART*IZ songs has been added to spotify_albums dictionary
# Album COLOR*IZ songs has been added to spotify_albums dictionary
# Album Love & Evil songs has been added to spotify_albums dictionary
# Album Max & Match songs has been added to spotify_albums dictionary
# Album GO LIVE songs has been added to spotify_albums dictionary
# Album GO LIVE songs has been added to spotify_albums dictionary
# Album SKZ2020 songs has been added to spotify_albums dictionary
# Album SKZ2020 songs has been added to spotify_albums dictionary
# Album Clé : LEVANTER songs has been added to spotify_albums dictionary
# Album Cle : LEVANTER songs has been added to spotify_albums dictionary
# Album UNVEIL Stray Kids songs has been added to spotify_albums dictionary
# Album Clé 2 : Yellow Wood songs has been added to spotify_albums dictionary
# Album Clé 1 : MIROH songs has been added to spotify_albums dictionary
# Album I am YOU songs has been added to spotify_albums dictionary
# Album I am WHO songs has been added to spotify_albums dictionary
# Album I am NOT songs has been added to spotify_albums dictionary
# Album Mixtape songs has been added to spotify_albums dictionary
# Album MORE & MORE songs has been added to spotify_albums dictionary
# Album MORE & MORE songs has been added to spotify_albums dictionary
# Album &TWICE (Repackage) songs has been added to spotify_albums dictionary
# Album &TWICE (Repackage) songs has been added to spotify_albums dictionary
# Album &TWICE songs has been added to spotify_albums dictionary
# Album &TWICE songs has been added to spotify_albums dictionary
# Album Feel Special songs has been added to spotify_albums dictionary
# Album Feel Special songs has been added to spotify_albums dictionary
# Album BDZ (Repackage) songs has been added to spotify_albums dictionary
# Album The year of "YES" songs has been added to spotify_albums dictionary
# Album The year of "YES" songs has been added to spotify_albums dictionary
# Album YES or YES songs has been added to spotify_albums dictionary
# Album YES or YES songs has been added to spotify_albums dictionary
# Album BDZ songs has been added to spotify_albums dictionary
# Album Summer Nights songs has been added to spotify_albums dictionary
# Album Summer Nights songs has been added to spotify_albums dictionary
# Album Merry & Happy songs has been added to spotify_albums dictionary
# Album Merry & Happy songs has been added to spotify_albums dictionary
# Album twicetagram songs has been added to spotify_albums dictionary
# Album Twicetagram songs has been added to spotify_albums dictionary

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    #create a track counter
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 9.510751962661743 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 19.52154564857483 seconds
# 15 playlists completed
# Loop #: 15
# Elapsed Time: 28.704501390457153 seconds
# 20 playlists completed
# Loop #: 20
# Elapsed Time: 39.90841770172119 seconds
# 25 playlists completed
# Loop #: 25
# Elapsed Time: 46.917831897735596 seconds
# 30 playlists completed
# Loop #: 30
# Elapsed Time: 54.48997688293457 seconds
# 35 playlists completed
# Loop #: 35
# Elapsed Time: 62.294519901275635 seconds
# 40 playlists completed
# Loop #: 40
# Elapsed Time: 70.5779128074646 seconds
# 45 playlists completed
# Loop #: 45
# Elapsed Time: 79.6187436580658 seconds

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])
# Out:
# 469

# %%
import pandas as pd
df = pd.DataFrame.from_dict(dic_df)
df
# Out:
#      acousticness                                              album  \
# 0         0.04960  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 1         0.09550  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 2         0.29000  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 3         0.01270  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 4         0.21800  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 5         0.04840  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 6         0.07670  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 7         0.06140  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 8         0.11300  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 9         0.13300  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 10        0.02280  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 11        0.15300  BLACKPINK 2019-2020 WORLD TOUR IN YOUR AREA -T...
# 12        0.01840    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 13        0.06750    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 14        0.27600    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 15        0.03190    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 16        0.46900    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 17        0.08720    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 18        0.13200    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 19        0.00924    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 20        0.04760    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 21        0.07860    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 22        0.19000    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 23        0.14000    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 24        0.04130    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 25        0.59400    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL (Live)
# 26        0.01840    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live
# 27        0.06750    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live
# 28        0.27600    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live
# 29        0.03190    BLACKPINK 2018 TOUR 'IN YOUR AREA' SEOUL - Live
# ..            ...                                                ...
# 439       0.25100                                      Merry & Happy
# 440       0.05740                                      Merry & Happy
# 441       0.28600                                      Merry & Happy
# 442       0.84800                                      Merry & Happy
# 443       0.43100                                        twicetagram
# 444       0.55300                                        twicetagram
# 445       0.21200                                        twicetagram
# 446       0.35500                                        twicetagram
# 447       0.12500                                        twicetagram
# 448       0.05570                                        twicetagram
# 449       0.07430                                        twicetagram
# 450       0.14600                                        twicetagram
# 451       0.04020                                        twicetagram
# 452       0.25100                                        twicetagram
# 453       0.05740                                        twicetagram
# 454       0.28600                                        twicetagram
# 455       0.84800                                        twicetagram
# 456       0.42000                                        Twicetagram
# 457       0.55300                                        Twicetagram
# 458       0.21500                                        Twicetagram
# 5      -6.226  Don’t Know What To Do - JP Ver./ BLACKPINK 201...          49
# 6      -4.182  REALLY - JP Ver./ BLACKPINK 2019-2020 WORLD TO...          48
# 7      -5.265  SEE U LATER - JP Ver./ BLACKPINK 2019-2020 WOR...          47
# 8      -5.240  PLAYING WITH FIRE - JP Ver./ BLACKPINK 2019-20...          47
# 9      -5.435  Kick It - JP Ver./ BLACKPINK 2019-2020 WORLD T...          47
# 10     -4.977  BOOMBAYAH - JP Ver./ BLACKPINK 2019-2020 WORLD...          48
# 11     -3.971  AS IF IT’S YOUR LAST - JP Ver./ BLACKPINK 2019...          47
# 12     -4.635                               DDU-DU DDU-DU - Live          57
# 13     -4.592                               Forever Young - Live          45
# 14     -4.999                        STAY (Remix Version) - Live          43
# 15     -5.183                                     WHISTLE - Live          43
# 16     -6.170                   YOU & I + ONLY LOOK AT ME - Live          46
# 17     -6.755                                        SOLO - Live          46
# 18     -4.433                     Really (Reggae Version) - Live          43
# 19     -5.421                                 See U Later - Live          42
# 20     -4.842                           PLAYING WITH FIRE - Live          43
# 21     -4.388                                   BOOMBAYAH - Live          44
# 22     -3.866                        As If It's Your Last - Live          43
# 23     -3.781                     WHISTLE (Remix Version) - Live          42
# 24     -3.411                  DDU DDU-DU (Remix Version) - Live          43
# 25     -8.777                                        STAY - Live          41
# 26     -4.635                               DDU-DU DDU-DU - Live          58
# 27     -4.592                               Forever Young - Live          47
# 28     -4.999                                STAY - Live - Remix          46
# 29     -5.183                                     WHISTLE - Live          45
# ..        ...                                                ...         ...
# 439    -4.600                                          LOVE LINE          22
# 440    -5.843                                      DON'T GIVE UP          25
# 441    -4.145                                    YOU IN MY HEART          28
# 442    -8.300                                 JALJAYO GOOD NIGHT          26
# 443    -1.081                                              LIKEY          56
# 444    -3.428                                             TURTLE          46
# 445    -3.387                                          MISSING U          36
# 446    -3.459                                                WOW          26
# 447    -2.145                                                FFW          27
# 448    -3.292                                          DING DONG          25
# 449    -4.107                                               24/7          29
# 450    -3.375                                         LOOK AT ME          35
# 451    -5.116                                            ROLLIN'          25
# 452    -4.600                                          LOVE LINE          31
# 453    -5.843                                      DON'T GIVE UP          25
# 454    -4.145                                    YOU IN MY HEART          32
# 455    -8.300                                 JALJAYO GOOD NIGHT          34
# 456    -1.261                                              Likey          69
# 457    -3.595                                             Turtle          54
# 458    -3.686                                          Missing U          48
# 459    -3.654                                                Wow          41
# 460    -2.324                                                Ffw          42
# 461    -3.460                                          Ding Dong          40
# 462    -4.293                                               24/7          45
# 463    -3.585                                         Look At Me          46
# 464    -5.313                                            Rollin'          41
# 465    -4.719                                          Love Line          45
# 466    -6.081                                      Don't Give Up          40
# 467    -4.345                                    You In My Heart          45
# 468    -8.421                                 Jaljayo Good Night          49
#
#      speechiness    tempo  track_number                                   uri  \
# 0         0.1190  139.943             1  spotify:track:7fqjqOu4HKTN2yP6aV8lpQ
# 1         0.2110  114.654             2  spotify:track:3F7VrA3ttl6i6Z4b2KJ9YR
# 2         0.0412   88.005             3  spotify:track:7pt16OMGqeqivEeI1PzkfC
# 447       0.0465  127.984             5  spotify:track:1qLn52MB7LOWt3TYvrAn1a
# 448       0.0531  149.998             6  spotify:track:7j5keEifFIjiTz9HovXBh1
# 449       0.0728  123.072             7  spotify:track:63byDH5VIbZkQ9Kt2HDwIR
# 450       0.0389  134.898             8  spotify:track:5AHS8rvrlaiW66d32DqNSg
# 451       0.0428  122.014             9  spotify:track:3sqONCpr1aAqxihn48OVQl
# 452       0.0437   95.019            10  spotify:track:2hwkgh4md78Rs0Nq4HN5v3
# 453       0.0456  102.982            11  spotify:track:5LH49TmiLoM5TNM8iaPPxP
# 454       0.0331  102.988            12  spotify:track:6nfx5va3KMUaeYdi517Fir
# 455       0.0344  133.979            13  spotify:track:1eaCZxdjrLOSwRxkz4kGZV
# 456       0.0331  132.006             1  spotify:track:4P66rfizAl2nIJCICSMymC
# 457       0.1340   94.986             2  spotify:track:1YaPqQfNDIx8mvcW5pIeE4
# 458       0.0476  119.965             3  spotify:track:4FW8Ty8M7iyKIk2wwNKlcM
# 459       0.1570  160.127             4  spotify:track:4twR4vaaqvMbay7jlXCBgl
# 460       0.0450  127.965             5  spotify:track:0iDyfwY9Yud1i20Q95c4q8
# 461       0.0534  150.019             6  spotify:track:5Yw9IvodOBXAkP7zQTAfbr
# 462       0.0681  123.065             7  spotify:track:7qJz1gaEgYtx4UJHtOGoJO
# 463       0.0365  134.892             8  spotify:track:2WL1smzwRRjabdSbvV4wKF
# 464       0.0446  122.023             9  spotify:track:5TUIKBmNcWqdwie8kV6mKr
# 465       0.0444   94.998            10  spotify:track:203sd4cosoKgF62jSkqd6z
# 466       0.0474  102.992            11  spotify:track:4FTczdvR53jxxp6qPBcNMg
# 467       0.0328  102.996            12  spotify:track:1nUIe8iHQitSldWAuB5AHp
# 468       0.0332  133.953            13  spotify:track:14WRue4qjZzL9Bo6q53iwx
#
#      valence
# 0      0.422
# 1      0.479
# 2      0.514
# 3      0.611
# 4      0.409
# 5      0.383
# 6      0.793
# 7      0.624
# 8      0.645
# 9      0.443
# 10     0.468
# 11     0.586
# 12     0.359
# 13     0.371
# 14     0.456
# 15     0.511
# 16     0.208
# 17     0.239
# 18     0.770
# 19     0.494
# 20     0.462
# 21     0.409
# 22     0.428
# 23     0.532
# 24     0.379
# 25     0.489
# 26     0.359
# 27     0.371
# 28     0.456
# 29     0.511
# ..       ...
# 439    0.542
# 440    0.414
# 441    0.382
# 442    0.359
# 443    0.394
# 444    0.609
# 445    0.833
# 446    0.909
# 447    0.895
# 448    0.824
# 449    0.558
# 450    0.662
# 451    0.272
# 452    0.542
# 453    0.414
# 454    0.382
# 455    0.359
# 456    0.445
# 457    0.615
# 458    0.856
# 459    0.928
# 460    0.916
# 461    0.818
# 462    0.531
# 463    0.665
# 464    0.244
# 465    0.519
# 466    0.454
# 467    0.392
# 468    0.361
#
# [469 rows x 15 columns]

# %%
print(len(df)) #lenght of dataframe with all the scraped data
final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index() #remove duplicates
print(len(final_df)) #length of dataframe after removing the duplicate values
# Out:
# 469
# 267

# %%
final_df.to_csv("spotify.csv")
#Save CSV on local disk
